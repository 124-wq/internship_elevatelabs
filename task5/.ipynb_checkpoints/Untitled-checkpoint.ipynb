# %%
import numpy as np
import pandas as pd

sales = pd.read_csv('python_practice_dataset.csv')
sales
# Out:
#       ID      Name  Age  Gender      Country   Join_Date  Purchase_Amount  \
# 0      1      Paul   56    Male        India  2022-09-22            12143
# 1      2    Walter   46  Female     Pakistan  2022-09-07             3540
# 2      3   Charles   32  Female   Bangladesh  2024-01-22             5744
# 3      4     Shawn   25    Male     Pakistan  2024-02-27            10618
# 4      5    Joseph   38    Male     Pakistan  2024-06-19            14652
# ..   ...       ...  ...     ...          ...         ...              ...
# 495  496   Spencer   56  Female   Bangladesh  2023-05-14             4551
# 496  497    Austin   49  Female    Sri Lanka  2023-07-30            15443
# 497  498    Alicia   41    Male  Afghanistan  2024-05-11            13735
# 498  499       Amy   40    Male   Bangladesh  2025-03-14             6059
# 499  500  Danielle   49  Female        Nepal  2023-05-17              226
#
#     Product_Category  Rating
# 0          Furniture     1.6
# ...

# %%
import matplotlib.pyplot as plt
sales['Country'].value_counts().plot(kind ='pie')
# Out:
# <Axes: ylabel='count'>

# %%
sales['Gender'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
total_sales = sales['Purchase_Amount'].sum()
total_sales
# Out:
# np.int64(4957478)

# %%
print(sales.groupby("Country")["Purchase_Amount"].sum())
print(sales.groupby("Gender")["Purchase_Amount"].sum())
# Out:
# Gender
# Female    2632213
# Male      2325265
# Name: Purchase_Amount, dtype: int64
